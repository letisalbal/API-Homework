# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key
temp_units = "imperial"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 654

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Open Weather Map API Key
api_key = "93ae705d5ab6add3a028442d898e75be"

#Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Prieska
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=prieska
# Processing Record 2 | Venancio Aires
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=venancio aires
# City not found. Skipping...
# Processing Record 3 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=busselton
# Processing Record 4 | Dickinson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=dickinson
# Processing Record 5 | Penzance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=penzance
# Processing Record 6 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=luderitz
# Processing Record 7 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=punta arenas
# Processing Record 8 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bluff
# Processing Record 9 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ushuaia
# Processing Record 10 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=thompson
# Processing Record 11 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=katsuura
# Processing Record 12 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=taoudenni
# City not found. Skipping...
# Processing Record 13 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=saint-philippe
# Processing Record 14 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=jamestown
# Processing Record 15 | Opochka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=opochka
# Processing Record 16 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=itarema
# Processing Record 17 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bredasdorp
# Processing Record 18 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=mataura
# Processing Record 19 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=cape town
# Processing Record 20 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=port-gentil
# Processing Record 21 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=tuktoyaktuk
# Processing Record 22 | Valderrama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=valderrama
# Processing Record 23 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=atuona
# Processing Record 24 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=albany
# City not found. Skipping...
# Processing Record 25 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=vaini
# Processing Record 26 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=khatanga
# Processing Record 27 | Ossora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ossora
# Processing Record 28 | San Andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=san andres
# Processing Record 29 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kapaa
# Processing Record 30 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=torbay
# Processing Record 31 | Oltu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=oltu
# Processing Record 32 | Itabira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=itabira
# Processing Record 33 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=te anau
# Processing Record 34 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=butaritari
# Processing Record 35 | Jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=jalu
# Processing Record 36 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sitka
# Processing Record 37 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=shingu
# City not found. Skipping...
# Processing Record 38 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hervey bay
# Processing Record 39 | Thunder Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=thunder bay
# Processing Record 40 | Shenkursk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=shenkursk
# Processing Record 41 | Udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=udachnyy
# City not found. Skipping...
# Processing Record 42 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=karratha
# Processing Record 43 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=avarua
# Processing Record 44 | Oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=oktyabrskoye
# Processing Record 45 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=saint george
# Processing Record 46 | Chibombo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=chibombo
# Processing Record 47 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=tasiilaq
# Processing Record 48 | Farmington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=farmington
# Processing Record 49 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=tiksi
# Processing Record 50 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=nikolskoye
# Processing Record 51 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lebu
# Processing Record 52 | Deep River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=deep river
# City not found. Skipping...
# Processing Record 53 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=salalah
# City not found. Skipping...
# Processing Record 54 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kodiak
# Processing Record 55 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lagoa
# Processing Record 56 | Boguchany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=boguchany
# Processing Record 57 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bambous virieux
# Processing Record 58 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=yellowknife
# Processing Record 59 | Tungor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=tungor
# City not found. Skipping...
# Processing Record 60 | Weinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=weinan
# Processing Record 61 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=puerto ayora
# City not found. Skipping...
# Processing Record 62 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hithadhoo
# Processing Record 63 | Toamasina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=toamasina
# Processing Record 64 | Tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=tiarei
# Processing Record 65 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hobart
# Processing Record 66 | Namalenga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=namalenga
# Processing Record 67 | Sayyan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sayyan
# Processing Record 68 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=castro
# Processing Record 69 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=port elizabeth
# Processing Record 70 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=rikitea
# Processing Record 71 | Bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bereda
# Processing Record 72 | Marquette
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=marquette
# Processing Record 73 | Port Hawkesbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=port hawkesbury
# Processing Record 74 | Dubti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=dubti
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 75 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=port alfred
# Processing Record 76 | Nouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=nouakchott
# Processing Record 77 | Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kenai
# City not found. Skipping...
# Processing Record 78 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=cherskiy
# Processing Record 79 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=mahebourg
# City not found. Skipping...
# Processing Record 80 | Djibo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=djibo
# Processing Record 81 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hermanus
# Processing Record 82 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=vila velha
# Processing Record 83 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=mar del plata
# Processing Record 84 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hilo
# Processing Record 85 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=saldanha
# Processing Record 86 | Alekseyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=alekseyevka
# Processing Record 87 | Grenada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=grenada
# Processing Record 88 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=pisco
# Processing Record 89 | Santiago del Estero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=santiago del estero
# Processing Record 90 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=yerbogachen
# Processing Record 91 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=margate
# Processing Record 92 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bethel
# Processing Record 93 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=airai
# Processing Record 94 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ancud
# Processing Record 95 | Urubamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=urubamba
# Processing Record 96 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=nome
# City not found. Skipping...
# Processing Record 97 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=longyearbyen
# Processing Record 98 | Chippewa Falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=chippewa falls
# Processing Record 99 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ilulissat
# Processing Record 100 | Porto Calvo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=porto calvo
# Processing Record 101 | Sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sechura
# Processing Record 102 | Springdale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=springdale
# Processing Record 103 | Sao Miguel do Araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sao miguel do araguaia
# Processing Record 104 | Puerto Escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=puerto escondido
# Processing Record 105 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=saskylakh
# Processing Record 106 | Ust-Koksa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ust-koksa
# Processing Record 107 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lompoc
# Processing Record 108 | Punta de Piedra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=punta de piedra
# Processing Record 109 | Cienfuegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=cienfuegos
# Processing Record 110 | Kjollefjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kjollefjord
# Processing Record 111 | Tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=tiznit
# Processing Record 112 | Otorohanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=otorohanga
# Processing Record 113 | Eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=eyl
# Processing Record 114 | Dharchula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=dharchula
# Processing Record 115 | Fuerte Olimpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=fuerte olimpo
# Processing Record 116 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lorengau
# Processing Record 117 | Posevnaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=posevnaya
# Processing Record 118 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=guerrero negro
# Processing Record 119 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hasaki
# City not found. Skipping...
# Processing Record 120 | Whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=whitehorse
# Processing Record 121 | Samagaltay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=samagaltay
# Processing Record 122 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=port hardy
# Processing Record 123 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kruisfontein
# Processing Record 124 | Igarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=igarka
# Processing Record 125 | Price
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=price
# Processing Record 126 | Bayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bayan
# Processing Record 127 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=camacha
# Processing Record 128 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=vostok
# Processing Record 129 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=dikson
# Processing Record 130 | Novi Pazar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=novi pazar
# Processing Record 131 | Terra Santa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=terra santa
# Processing Record 132 | Xiaoweizhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=xiaoweizhai
# Processing Record 133 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kaitangata
# Processing Record 134 | Launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=launceston
# Processing Record 135 | Bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bowen
# Processing Record 136 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=arraial do cabo
# Processing Record 137 | Fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=fukue
# City not found. Skipping...
# Processing Record 138 | San Jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=san jose
# City not found. Skipping...
# Processing Record 139 | Barranca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=barranca
# Processing Record 140 | Corner Brook
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=corner brook
# Processing Record 141 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=broome
# Processing Record 142 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=rocha
# Processing Record 143 | Paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=paita
# Processing Record 144 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=souillac
# Processing Record 145 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=muros
# Processing Record 146 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=qaanaaq
# Processing Record 147 | Tchibanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=tchibanga
# Processing Record 148 | Ayr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ayr
# Processing Record 149 | Porec
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=porec
# Processing Record 150 | Sedalia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sedalia
# Processing Record 151 | Kargil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kargil
# Processing Record 152 | Awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=awjilah
# Processing Record 153 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=pevek
# Processing Record 154 | Issia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=issia
# Processing Record 155 | Lander
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lander
# Processing Record 156 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=aklavik
# Processing Record 157 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=barrow
# Processing Record 158 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sao filipe
# Processing Record 159 | Hatillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hatillo
# Processing Record 160 | Ziway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ziway
# Processing Record 161 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=new norfolk
# Processing Record 162 | Bolivar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bolivar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 163 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ponta do sol
# Processing Record 164 | Aliwal North
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=aliwal north
# Processing Record 165 | Parana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=parana
# Processing Record 166 | Vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=vestmanna
# Processing Record 167 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=cayenne
# Processing Record 168 | Lalmohan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lalmohan
# Processing Record 169 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=faanui
# Processing Record 170 | Iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=iquique
# Processing Record 171 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hirara
# Processing Record 172 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=esperance
# Processing Record 173 | Lapua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lapua
# Processing Record 174 | Mastic Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=mastic beach
# Processing Record 175 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=coquimbo
# Processing Record 176 | Atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=atambua
# Processing Record 177 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=provideniya
# Processing Record 178 | Wanlaweyn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=wanlaweyn
# Processing Record 179 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=dunedin
# Processing Record 180 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kahului
# Processing Record 181 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=fairbanks
# Processing Record 182 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=pacific grove
# Processing Record 183 | Zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=zhezkazgan
# Processing Record 184 | Mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=mogadishu
# Processing Record 185 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=namatanai
# Processing Record 186 | Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lasa
# City not found. Skipping...
# Processing Record 187 | Bykovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bykovo
# Processing Record 188 | Paracuru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=paracuru
# Processing Record 189 | Mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=mezen
# Processing Record 190 | Kuusamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kuusamo
# Processing Record 191 | Maamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=maamba
# City not found. Skipping...
# Processing Record 192 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=buala
# City not found. Skipping...
# Processing Record 193 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ostrovnoy
# Processing Record 194 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=paamiut
# Processing Record 195 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=grindavik
# Processing Record 196 | Malindi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=malindi
# Processing Record 197 | Kirksville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kirksville
# Processing Record 198 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=cabo san lucas
# Processing Record 199 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=leningradskiy
# Processing Record 200 | Gold Coast
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=gold coast
# Processing Record 201 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=upernavik
# Processing Record 202 | Beatrice
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=beatrice
# Processing Record 203 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=carnarvon
# Processing Record 204 | Dabhol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=dabhol
# Processing Record 205 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ribeira grande
# Processing Record 206 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hambantota
# Processing Record 207 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=college
# Processing Record 208 | Poli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=poli
# Processing Record 209 | Praia da Vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=praia da vitoria
# Processing Record 210 | Balikpapan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=balikpapan
# Processing Record 211 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=east london
# Processing Record 212 | Selikhino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=selikhino
# Processing Record 213 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=iqaluit
# Processing Record 214 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=klaksvik
# Processing Record 215 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=nemuro
# Processing Record 216 | Kysyl-Syr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kysyl-syr
# Processing Record 217 | Arang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=arang
# Processing Record 218 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=severo-kurilsk
# City not found. Skipping...
# Processing Record 219 | Acari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=acari
# City not found. Skipping...
# Processing Record 220 | Sauk Rapids
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sauk rapids
# Processing Record 221 | Kaoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kaoma
# Processing Record 222 | Nipawin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=nipawin
# Processing Record 223 | Wanaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=wanaka
# Processing Record 224 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=victoria
# Processing Record 225 | Meridian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=meridian
# Processing Record 226 | Fort Wellington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=fort wellington
# Processing Record 227 | Hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hovd
# City not found. Skipping...
# Processing Record 228 | Hukuntsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hukuntsi
# Processing Record 229 | Kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kutum
# Processing Record 230 | Wieliczka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=wieliczka
# Processing Record 231 | Mokhsogollokh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=mokhsogollokh
# City not found. Skipping...
# Processing Record 232 | Ulagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ulagan
# Processing Record 233 | Nisia Floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=nisia floresta
# Processing Record 234 | Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=viedma
# Processing Record 235 | Araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=araouane
# Processing Record 236 | Akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=akdepe
# Processing Record 237 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lavrentiya
# Processing Record 238 | San Vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=san vicente
# Processing Record 239 | Ca Mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ca mau
# Processing Record 240 | Kikwit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kikwit
# Processing Record 241 | Sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sambava
# Processing Record 242 | Sao Jose da Coroa Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sao jose da coroa grande
# Processing Record 243 | Narrabri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=narrabri
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 244 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=meulaboh
# Processing Record 245 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bandarbeyla
# Processing Record 246 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ahipara
# Processing Record 247 | Deoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=deoria
# Processing Record 248 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=adrar
# Processing Record 249 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=marawi
# Processing Record 250 | Maturin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=maturin
# Processing Record 251 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=saint anthony
# Processing Record 252 | Veraval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=veraval
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 253 | Brownsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=brownsville
# Processing Record 254 | Lakselv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lakselv
# Processing Record 255 | Sarai Alamgir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sarai alamgir
# Processing Record 256 | Taman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=taman
# Processing Record 257 | Catia La Mar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=catia la mar
# Processing Record 258 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=yulara
# City not found. Skipping...
# Processing Record 259 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=constitucion
# Processing Record 260 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=rawson
# City not found. Skipping...
# Processing Record 261 | Macae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=macae
# Processing Record 262 | Surt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=surt
# Processing Record 263 | Batticaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=batticaloa
# Processing Record 264 | Ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ornskoldsvik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 265 | Hella
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hella
# Processing Record 266 | Ust-Ishim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ust-ishim
# Processing Record 267 | Swellendam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=swellendam
# Processing Record 268 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=touros
# Processing Record 269 | Nikko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=nikko
# Processing Record 270 | Areosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=areosa
# Processing Record 271 | North Battleford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=north battleford
# City not found. Skipping...
# Processing Record 272 | Pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=pochutla
# Processing Record 273 | Tripoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=tripoli
# City not found. Skipping...
# Processing Record 274 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=riyadh
# Processing Record 275 | Omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=omboue
# Processing Record 276 | Alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=alyangula
# City not found. Skipping...
# Processing Record 277 | Polunochnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=polunochnoye
# Processing Record 278 | Coolum Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=coolum beach
# Processing Record 279 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=raudeberg
# Processing Record 280 | Maraa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=maraa
# Processing Record 281 | Burley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=burley
# Processing Record 282 | Ilebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ilebo
# Processing Record 283 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hobyo
# Processing Record 284 | Macklin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=macklin
# Processing Record 285 | Monte Alegre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=monte alegre
# Processing Record 286 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=vardo
# Processing Record 287 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=half moon bay
# Processing Record 288 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=mehamn
# City not found. Skipping...
# Processing Record 289 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hofn
# Processing Record 290 | Saurimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=saurimo
# Processing Record 291 | Annau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=annau
# Processing Record 292 | Piritiba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=piritiba
# City not found. Skipping...
# Processing Record 293 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=alofi
# Processing Record 294 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=komsomolskiy
# Processing Record 295 | Carmen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=carmen
# Processing Record 296 | Sangar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sangar
# Processing Record 297 | Portneuf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=portneuf
# Processing Record 298 | Matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=matagami
# Processing Record 299 | Filadelfia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=filadelfia
# Processing Record 300 | Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=nelson bay
# Processing Record 301 | Zaraza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=zaraza
# Processing Record 302 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=caravelas
# Processing Record 303 | Tarboro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=tarboro
# Processing Record 304 | Brusque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=brusque
# City not found. Skipping...
# Processing Record 305 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=geraldton
# Processing Record 306 | Barreiras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=barreiras
# Processing Record 307 | Gubin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=gubin
# Processing Record 308 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=la ronge
# Processing Record 309 | Suluq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=suluq
# Processing Record 310 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=isangel
# Processing Record 311 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=saint-augustin
# Processing Record 312 | Brookhaven
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=brookhaven
# Processing Record 313 | Aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=aksu
# Processing Record 314 | Gotsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=gotsu
# City not found. Skipping...
# Processing Record 315 | Moranbah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=moranbah
# Processing Record 316 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=henties bay
# Processing Record 317 | Guaymas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=guaymas
# City not found. Skipping...
# Processing Record 318 | Poso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=poso
# Processing Record 319 | Boralday
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=boralday
# Processing Record 320 | Magdagachi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=magdagachi
# Processing Record 321 | Pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=pangody
# Processing Record 322 | Walvis Bay
# ...
# Processing Record 473 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=flinders
# Processing Record 474 | Iberia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=iberia
# Processing Record 475 | Den Helder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=den helder
# City not found. Skipping...
# Processing Record 476 | Sweetwater
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sweetwater
# Processing Record 477 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=namibe
# Processing Record 478 | Ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ixtapa
# Processing Record 479 | Lillooet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lillooet
# Processing Record 480 | Xinqing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=xinqing
# Processing Record 481 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=srednekolymsk
# Processing Record 482 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=san quintin
# Processing Record 483 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=avera
# Processing Record 484 | Enumclaw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=enumclaw
# Processing Record 485 | Jiayuguan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=jiayuguan
# Processing Record 486 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=san cristobal
# Processing Record 487 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lata
# Processing Record 488 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=berlevag
# Processing Record 489 | Claveria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=claveria
# Processing Record 490 | Duekoue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=duekoue
# Processing Record 491 | Belfast
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=belfast
# Processing Record 492 | Santa Fe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=santa fe
# Processing Record 493 | Tazmalt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=tazmalt
# Processing Record 494 | Bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bambanglipuro
# Processing Record 495 | Erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=erenhot
# Processing Record 496 | Taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=taltal
# City not found. Skipping...
# Processing Record 497 | Halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=halifax
# City not found. Skipping...
# Processing Record 498 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sioux lookout
# City not found. Skipping...
# Processing Record 499 | Peleduy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=peleduy
# Processing Record 500 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bilma
# City not found. Skipping...
# Processing Record 501 | Bom Jesus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bom jesus
# City not found. Skipping...
# Processing Record 502 | High Level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=high level
# Processing Record 503 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=havre-saint-pierre
# Processing Record 504 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=clyde river
# Processing Record 505 | Cangzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=cangzhou
# Processing Record 506 | Turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=turukhansk
# Processing Record 507 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=dingle
# Processing Record 508 | Presidencia Roque Saenz Pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=presidencia roque saenz pena
# City not found. Skipping...
# Processing Record 509 | Hammerfest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hammerfest
# City not found. Skipping...
# Processing Record 510 | Puerto Carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=puerto carreno
# Processing Record 511 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=los llanos de aridane
# City not found. Skipping...
# Processing Record 512 | Muriwai Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=muriwai beach
# Processing Record 513 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=fort nelson
# Processing Record 514 | Kindu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kindu
# Processing Record 515 | Adre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=adre
# Processing Record 516 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=yar-sale
# City not found. Skipping...
# Processing Record 517 | Knysna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=knysna
# Processing Record 518 | Ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ugoofaaru
# City not found. Skipping...
# Processing Record 519 | Mponela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=mponela
# Processing Record 520 | Cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=cabedelo
# Processing Record 521 | Herat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=herat
# City not found. Skipping...
# Processing Record 522 | Pascagoula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=pascagoula
# Processing Record 523 | Key Largo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=key largo
# Processing Record 524 | Khargupur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=khargupur
# Processing Record 525 | Dunmore Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=dunmore town
# Processing Record 526 | Barra dos Coqueiros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=barra dos coqueiros
# Processing Record 527 | Mollendo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=mollendo
# City not found. Skipping...
# Processing Record 528 | Khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=khasan
# Processing Record 529 | Fraserburgh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=fraserburgh
# Processing Record 530 | Ravenna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=ravenna
# Processing Record 531 | Filingue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=filingue
# City not found. Skipping...
# Processing Record 532 | Shizunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=shizunai
# Processing Record 533 | Calvinia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=calvinia
# Processing Record 534 | Petropavlovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=petropavlovka
# Processing Record 535 | Martapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=martapura
# Processing Record 536 | Emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=emerald
# City not found. Skipping...
# Processing Record 537 | Aguimes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=aguimes
# Processing Record 538 | Newport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=newport
# Processing Record 539 | Marovoay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=marovoay
# Processing Record 540 | Nara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=nara
# Processing Record 541 | Kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kiunga
# Processing Record 542 | Cabanas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=cabanas
# Processing Record 543 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=petropavlovsk-kamchatskiy
# Processing Record 544 | Changping
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=changping
# Processing Record 545 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=olinda
# Processing Record 546 | Lafayette
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lafayette
# Processing Record 547 | Junin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=junin
# Processing Record 548 | Bahia Blanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=bahia blanca
# Processing Record 549 | Kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kulhudhuffushi
# Processing Record 550 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=marzuq
# Processing Record 551 | Jining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=jining
# Processing Record 552 | Seddon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=seddon
# City not found. Skipping...
# Processing Record 553 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hualmay
# Processing Record 554 | Koygorodok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=koygorodok
# Processing Record 555 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=okhotsk
# City not found. Skipping...
# Processing Record 556 | Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=gat
# Processing Record 557 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=necochea
# Processing Record 558 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=fortuna
# Processing Record 559 | Hay River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=hay river
# Processing Record 560 | Goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=goderich
# Processing Record 561 | Zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=zhangye
# Processing Record 562 | Winnemucca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=winnemucca
# Processing Record 563 | Kaniama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=kaniama
# Processing Record 564 | Sinjai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=sinjai
# Processing Record 565 | Lokosovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=lokosovo
# Processing Record 566 | Mulchen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=mulchen
# Processing Record 567 | Mende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=mende
# Processing Record 568 | Beni Mazar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=beni mazar
# Processing Record 569 | Marsh Harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=marsh harbour
# Processing Record 570 | Maloy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=maloy
# Processing Record 571 | Evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=evensk
# Processing Record 572 | Jodhpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=jodhpur
# City not found. Skipping...
# Processing Record 573 | Leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=leshukonskoye
# Processing Record 574 | Semirom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=semirom
# Processing Record 575 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=vestmannaeyjar
# Processing Record 576 | Tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=tual
# City not found. Skipping...
# Processing Record 577 | Suleja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93ae705d5ab6add3a028442d898e75be&q=suleja

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          577
# Cloudiness    577
# Country       577
# Date          577
# Humidity      577
# Lat           577
# Lng           577
# Max Temp      577
# Wind Speed    577
# dtype: int64

# %%
# Save data frame to CSV
weather_data.to_csv('output.csv')

# Display data frame head 
weather_data.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         Prieska           0      ZA  1567437857         9 -29.67   22.74
# 1  Venancio Aires           0      BR  1567437738        68 -29.61  -52.19
# 2       Busselton          15      AU  1567437859        53 -33.64  115.35
# 3       Dickinson          90      US  1567437643        93  46.88 -102.79
# 4        Penzance          75      GB  1567437862        82  50.12   -5.53
#
#    Max Temp  Wind Speed
# 0     73.99        1.72
# 1     64.99        3.00
# 2     55.00       27.47
# 3     64.00       17.22
# 4     64.00       11.41

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("temp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("clouds.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("wind.png")

# Show plot
plt.show()

# %%
Observable Trends

1. As we approach the equator the temperatures increase. 
2. Cloudiness and Humidity do not show a correlation to Latitude.
3. As we move away from the equator, the speed of wind slightly increases.
